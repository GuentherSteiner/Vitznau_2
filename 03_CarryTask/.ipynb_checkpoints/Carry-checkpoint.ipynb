# %% [markdown]
# # Task Description

# %%
# The task would be to test a long-only stock-based carry/value strategy.

# Carry strategy in stocks would be to long high dividend yield stocks and short the reverse (in this case no need to do short).
# Whole value strategy you should be familiar with.

# Carry trade in rate hike periods work pretty well (for fx especially). We are interested in whether the same hold for value. 
# The underlying assets would be S&P 500 stocks.

# Please take into account that some companies do stock repurchase instead of cash dividend.
# You could try to find adjusted dividend yield data. Time horizon is up to you, but keep in mind potential survivorship bias.
# It might be interesting to check the strategy performance during different periods. 
# Remember to make the backtest a way that they could be implemented (not longing 100 stocks at the same time). 
# Have a nice night and good luck with your presentation on Monday.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Load Packages

# %%
#### Import required Packages ####
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import scipy as sp
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error # to calculate the MSE
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score

from statsmodels.graphics.tsaplots import plot_acf # To produce ACF plots
from statsmodels.graphics.tsaplots import plot_pacf # To produce PACF plots
from statsmodels.tsa.seasonal import seasonal_decompose # To decompose Seasons
from statsmodels.tsa.stattools import adfuller, kpss # Tests for Stationarity
from statsmodels.tsa.ar_model import AutoReg # To produce AR models
from statsmodels.stats.anova import anova_lm # To use ANOVA (compare nested models)
from statsmodels.tsa.arima.model import ARIMA # To build ARMA & ARIMA Models
import statsmodels.stats.diagnostic as dg # To get Breusch-Godfrey Test
from statsmodels.stats.stattools import durbin_watson



from datetime import datetime # to transform variables into datetime objects
import math # simple math functions
from math import sqrt # square root function
import statistics # descriptive statistics library
import scipy.stats as stats # descriptive statistics library from scipy
import matplotlib.dates as mdates # date formatting
from matplotlib.collections import PolyCollection, LineCollection # better plot options
# Out:
# C:\Users\Corinne Vogel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\Corinne Vogel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# ## Plotstyle

# %%
# Seaborn plot style ticks to have nicer looking plots
sb.set_style("ticks")
sb.mpl.rc("figure", figsize=(16,8))
sb.mpl.rc("font", size=14)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# %% [markdown]
# ## LoadData

# %%
# Loading Data (takes some time)

div = pd.read_excel("02_Data_clean/SPX_div_clean_Nick.xlsx", parse_dates=["Date"])
ret = pd.read_excel("02_Data_clean/SPX_px_clean_Nick.xlsx", parse_dates=["Date"])

# Check
# print(type(div))
# print(div.dtypes)
# print(type(ret))
# print(ret.dtypes)

# %%
# set date columns as indices

ret.set_index(['Date'], inplace = True)
#ret.head()

# %% [markdown]
# ## Data Cleaning

# %%
# Resample monthly returns (takes some time)
mtl_ret = ret.pct_change().resample("M").agg(lambda x: ((1+x).prod()-1)) # pct_change creates ordinary returns, resample Monthly and aggregating with the (1+x) -1 formula to get monthly ordinary returns

# df = pd.concat([data, data2], axis=1) # concating dfs
# data.set_index("Date", inplace=True) # set datetimeindex

# %% [markdown]
# ## Sorting the signal

# %%
# in a first step we create a dataframe which we will fill with the weights of the carry strategy each month
### Important ### for carry we should use the (expected) dividend yield minus the riskfree ### Important ###
divv = div
cols = (divv.columns[1:])
rows = divv.iloc[:,0]

weights = pd.DataFrame(index = rows, columns = (cols))
weights = weights.resample("M").mean()

# %%
weights
# Out:
#             AEE UN Equity  ITT UN Equity  UN UN Equity  APD UN Equity  \
# Date
# 1999-12-31            NaN            NaN           NaN            NaN
# 2000-01-31            NaN            NaN           NaN            NaN
# 2000-02-29            NaN            NaN           NaN            NaN
# 2000-03-31            NaN            NaN           NaN            NaN
# 2000-04-30            NaN            NaN           NaN            NaN
# ...                   ...            ...           ...            ...
# 2022-08-31            NaN            NaN           NaN            NaN
# 2022-09-30            NaN            NaN           NaN            NaN
# 2022-10-31            NaN            NaN           NaN            NaN
# 2022-11-30            NaN            NaN           NaN            NaN
# 2022-12-31            NaN            NaN           NaN            NaN
#
#             RDPL UN Equity  GOLD UN Equity  VZ UN Equity  CAT UN Equity  \
# Date
# 1999-12-31             NaN             NaN           NaN            NaN
# 2000-01-31             NaN             NaN           NaN            NaN
# 2000-02-29             NaN             NaN           NaN            NaN
# 2000-03-31             NaN             NaN           NaN            NaN
# 2000-04-30             NaN             NaN           NaN            NaN
# ...                    ...             ...           ...            ...
# 2022-08-31             NaN             NaN           NaN            NaN
# 2022-09-30             NaN             NaN           NaN            NaN
# 2022-10-31             NaN             NaN           NaN            NaN
# 2022-11-30             NaN             NaN           NaN            NaN
# 2022-12-31             NaN             NaN           NaN            NaN
#
#             CVX UN Equity  KO UN Equity  ...  PTC UQ Equity  QCOM UQ Equity  \
# Date                                     ...
# 1999-12-31            NaN           NaN  ...            NaN             NaN
# 2000-01-31            NaN           NaN  ...            NaN             NaN
# 2000-02-29            NaN           NaN  ...            NaN             NaN
# 2000-03-31            NaN           NaN  ...            NaN             NaN
# 2000-04-30            NaN           NaN  ...            NaN             NaN
# ...                   ...           ...  ...            ...             ...
# 2022-08-31            NaN           NaN  ...            NaN             NaN
# 2022-09-30            NaN           NaN  ...            NaN             NaN
# 2022-10-31            NaN           NaN  ...            NaN             NaN
# 2022-11-30            NaN           NaN  ...            NaN             NaN
# 2022-12-31            NaN           NaN  ...            NaN             NaN
#
#             SPLS UQ Equity  XLNX UQ Equity  1519128D UQ Equity  \
# Date
# 1999-12-31             NaN             NaN                 NaN
# 2000-01-31             NaN             NaN                 NaN
# 2000-02-29             NaN             NaN                 NaN
# 2000-03-31             NaN             NaN                 NaN
# 2000-04-30             NaN             NaN                 NaN
# ...                    ...             ...                 ...
# 2022-08-31             NaN             NaN                 NaN
# 2022-09-30             NaN             NaN                 NaN
# 2022-10-31             NaN             NaN                 NaN
# 2022-11-30             NaN             NaN                 NaN
# 2022-12-31             NaN             NaN                 NaN
#
#             NTAP UQ Equity  CTXS UQ Equity  9990253D UN Equity  \
# Date
# 1999-12-31             NaN             NaN                 NaN
# 2000-01-31             NaN             NaN                 NaN
# 2000-02-29             NaN             NaN                 NaN
# 2000-03-31             NaN             NaN                 NaN
# 2000-04-30             NaN             NaN                 NaN
# ...                    ...             ...                 ...
# 2022-08-31             NaN             NaN                 NaN
# 2022-09-30             NaN             NaN                 NaN
# 2022-10-31             NaN             NaN                 NaN
# 2022-11-30             NaN             NaN                 NaN
# 2022-12-31             NaN             NaN                 NaN
#
#             0948669D UN Equity  CMCSK UQ Equity
# Date
# 1999-12-31                 NaN              NaN
# 2000-01-31                 NaN              NaN
# 2000-02-29                 NaN              NaN
# 2000-03-31                 NaN              NaN
# 2000-04-30                 NaN              NaN
# ...                        ...              ...
# 2022-08-31                 NaN              NaN
# 2022-09-30                 NaN              NaN
# 2022-10-31                 NaN              NaN
# 2022-11-30                 NaN              NaN
# 2022-12-31                 NaN              NaN
#
# [277 rows x 500 columns]

# %%
# the approach is as follows: 
# 1. take a moving average of the 12 month previous carry signal, ignoring the most recent month
# 2. for each month calculate the 10 stocks considered for the long strategy
# 3. calculate the PF return
# 4. take into account the transaction costs

div = div.set_index(['Date'])

# %%
# resample the data monthly and take the avg of the div yield

div = div.resample('M').mean()
#div

# %%
# 1. take a moving average of the 12 month previous carry signal, ignoring the most recent month

# omitted at first for simpler calculations

# %%
# 2. for each month calculate the 10 stocks considered for the long strategy (takes some time)

for i in div.index:
    x = div.loc[i,:].nlargest(10)
    for j in div.columns:
        if j in x.index:
            weights.loc[i,j] = 0.1
        else:
            weights.loc[i,j] = 0
weights
# Out:
#             AEE UN Equity  ITT UN Equity  UN UN Equity  APD UN Equity  \
# Date
# 1999-12-31            0.0            0.1           0.0            0.0
# 2000-01-31            0.0            0.1           0.0            0.0
# 2000-02-29            0.0            0.1           0.0            0.0
# 2000-03-31            0.0            0.1           0.0            0.0
# 2000-04-30            0.0            0.1           0.0            0.0
# ...                   ...            ...           ...            ...
# 2022-08-31            0.0            0.0           0.0            0.0
# 2022-09-30            0.0            0.0           0.0            0.0
# 2022-10-31            0.0            0.0           0.0            0.0
# 2022-11-30            0.0            0.0           0.0            0.0
# 2022-12-31            0.0            0.0           0.0            0.0
#
#             RDPL UN Equity  GOLD UN Equity  VZ UN Equity  CAT UN Equity  \
# Date
# 1999-12-31             0.0             0.0           0.0            0.0
# 2000-01-31             0.0             0.0           0.0            0.0
# 2000-02-29             0.0             0.0           0.0            0.0
# 2000-03-31             0.0             0.0           0.0            0.0
# 2000-04-30             0.0             0.0           0.0            0.0
# ...                    ...             ...           ...            ...
# 2022-08-31             0.0             0.0           0.1            0.0
# 2022-09-30             0.0             0.0           0.1            0.0
# 2022-10-31             0.0             0.0           0.1            0.0
# 2022-11-30             0.0             0.0           0.1            0.0
# 2022-12-31             0.0             0.0           0.1            0.0
#
#             CVX UN Equity  KO UN Equity  ...  PTC UQ Equity  QCOM UQ Equity  \
# Date                                     ...
# 1999-12-31            0.0           0.0  ...            0.0             0.0
# 2000-01-31            0.0           0.0  ...            0.0             0.0
# 2000-02-29            0.0           0.0  ...            0.0             0.0
# 2000-03-31            0.0           0.0  ...            0.0             0.0
# 2000-04-30            0.0           0.0  ...            0.0             0.0
# ...                   ...           ...  ...            ...             ...
# 2022-08-31            0.0           0.0  ...            0.0             0.0
# 2022-09-30            0.0           0.0  ...            0.0             0.0
# 2022-10-31            0.0           0.0  ...            0.0             0.0
# 2022-11-30            0.0           0.0  ...            0.0             0.0
# 2022-12-31            0.0           0.0  ...            0.0             0.0
#
#             SPLS UQ Equity  XLNX UQ Equity  1519128D UQ Equity  \
# Date
# 1999-12-31             0.0             0.0                 0.0
# 2000-01-31             0.0             0.0                 0.0
# 2000-02-29             0.0             0.0                 0.0
# 2000-03-31             0.0             0.0                 0.0
# 2000-04-30             0.0             0.0                 0.0
# ...                    ...             ...                 ...
# 2022-08-31             0.0             0.0                 0.0
# 2022-09-30             0.0             0.0                 0.0
# 2022-10-31             0.0             0.0                 0.0
# 2022-11-30             0.0             0.0                 0.0
# 2022-12-31             0.0             0.0                 0.0
#
#             NTAP UQ Equity  CTXS UQ Equity  9990253D UN Equity  \
# Date
# 1999-12-31             0.0             0.0                 0.0
# 2000-01-31             0.0             0.0                 0.0
# 2000-02-29             0.0             0.0                 0.0
# 2000-03-31             0.0             0.0                 0.0
# 2000-04-30             0.0             0.0                 0.0
# ...                    ...             ...                 ...
# 2022-08-31             0.0             0.0                 0.0
# 2022-09-30             0.0             0.0                 0.0
# 2022-10-31             0.0             0.0                 0.0
# 2022-11-30             0.0             0.0                 0.0
# 2022-12-31             0.0             0.0                 0.0
#
#             0948669D UN Equity  CMCSK UQ Equity
# Date
# 1999-12-31                 0.0              0.0
# 2000-01-31                 0.0              0.0
# 2000-02-29                 0.0              0.0
# 2000-03-31                 0.0              0.0
# 2000-04-30                 0.0              0.0
# ...                        ...              ...
# 2022-08-31                 0.0              0.0
# 2022-09-30                 0.0              0.0
# 2022-10-31                 0.0              0.0
# 2022-11-30                 0.0              0.0
# 2022-12-31                 0.0              0.0
#
# [277 rows x 500 columns]

# %% [markdown]
# ## Return calculation

# %%
# in a first step we create a dataframe which we will fill with the weighted returns of the carry strategy each month

weighted_ret = weights

# %%
for i in weighted_ret.index:
    for j in weighted_ret.columns:
        weighted_ret.loc[i,j] = weighted_ret.loc[i,j]*mtl_ret.loc[i,j]
        
weighted_ret['PF_ret'] = 0
weighted_ret
# Out:
# <ipython-input-12-d163deff6985>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   weighted_ret['PF_ret'] = 0
#             AEE UN Equity  ITT UN Equity  UN UN Equity  APD UN Equity  \
# Date
# 1999-12-31            0.0       0.000000           0.0            0.0
# 2000-01-31           -0.0      -0.006169          -0.0           -0.0
# 2000-02-29           -0.0      -0.025896          -0.0           -0.0
# 2000-03-31            0.0       0.033601           0.0            0.0
# 2000-04-30            0.0       0.001610          -0.0            0.0
# ...                   ...            ...           ...            ...
# 2022-08-31            0.0       0.000000           0.0            0.0
# 2022-09-30           -0.0      -0.000000           0.0           -0.0
# 2022-10-31            0.0       0.000000           0.0            0.0
# 2022-11-30            0.0       0.000000           0.0            0.0
# 2022-12-31           -0.0       0.000000           0.0            0.0
#
#             RDPL UN Equity  GOLD UN Equity  VZ UN Equity  CAT UN Equity  \
# Date
# 1999-12-31             0.0             0.0      0.000000            0.0
# 2000-01-31            -0.0            -0.0     -0.000000           -0.0
# 2000-02-29            -0.0             0.0     -0.000000           -0.0
# 2000-03-31             0.0            -0.0      0.000000            0.0
# 2000-04-30            -0.0             0.0     -0.000000           -0.0
# ...                    ...             ...           ...            ...
# 2022-08-31             0.0            -0.0     -0.006365           -0.0
# 2022-09-30             0.0             0.0     -0.012208           -0.0
# 2022-10-31             0.0            -0.0     -0.000790            0.0
# 2022-11-30             0.0             0.0      0.003584            0.0
# 2022-12-31             0.0             0.0     -0.002153            0.0
#
#             CVX UN Equity  KO UN Equity  ...  QCOM UQ Equity  SPLS UQ Equity  \
# Date                                     ...
# 1999-12-31            0.0           0.0  ...             0.0             0.0
# 2000-01-31           -0.0          -0.0  ...            -0.0             0.0
# 2000-02-29           -0.0          -0.0  ...             0.0             0.0
# 2000-03-31            0.0          -0.0  ...             0.0            -0.0
# 2000-04-30           -0.0           0.0  ...            -0.0            -0.0
# ...                   ...           ...  ...             ...             ...
# 2022-08-31           -0.0          -0.0  ...            -0.0             0.0
# 2022-09-30           -0.0          -0.0  ...            -0.0             0.0
# 2022-10-31            0.0           0.0  ...             0.0             0.0
# 2022-11-30            0.0           0.0  ...             0.0             0.0
# 2022-12-31           -0.0           0.0  ...             0.0             0.0
#
#             XLNX UQ Equity  1519128D UQ Equity  NTAP UQ Equity  \
# Date
# 1999-12-31             0.0                 0.0             0.0
# 2000-01-31            -0.0                -0.0             0.0
# 2000-02-29             0.0                -0.0             0.0
# 2000-03-31             0.0                -0.0            -0.0
# 2000-04-30            -0.0                -0.0            -0.0
# ...                    ...                 ...             ...
# 2022-08-31             0.0                 0.0             0.0
# 2022-09-30             0.0                 0.0            -0.0
# 2022-10-31             0.0                 0.0             0.0
# 2022-11-30             0.0                 0.0             0.0
# 2022-12-31             0.0                 0.0            -0.0
#
#             CTXS UQ Equity  9990253D UN Equity  0948669D UN Equity  \
# Date
# 1999-12-31             0.0                 0.0                 0.0
# 2000-01-31             0.0                -0.0                -0.0
# 2000-02-29             0.0                -0.0                -0.0
# 2000-03-31            -0.0                 0.0                 0.0
# 2000-04-30            -0.0                 0.0                -0.0
# ...                    ...                 ...                 ...
# 2022-08-31             0.0                 0.0                 0.0
# 2022-09-30             0.0                 0.0                 0.0
# 2022-10-31             0.0                 0.0                 0.0
# 2022-11-30             0.0                 0.0                 0.0
# 2022-12-31             0.0                 0.0                 0.0
#
#             CMCSK UQ Equity  PF_ret
# Date
# 1999-12-31              0.0       0
# 2000-01-31             -0.0       0
# 2000-02-29             -0.0       0
# 2000-03-31             -0.0       0
# 2000-04-30             -0.0       0
# ...                     ...     ...
# 2022-08-31              0.0       0
# 2022-09-30              0.0       0
# 2022-10-31              0.0       0
# 2022-11-30              0.0       0
# 2022-12-31              0.0       0
#
# [277 rows x 501 columns]

# %%
# now we sum over each row to calculate the PF return and put it in the respective columns

for i in weighted_ret.index:
    weighted_ret.loc[i,'PF_ret'] = weighted_ret.loc[i,:].sum()

weighted_ret
# Out:
#             AEE UN Equity  ITT UN Equity  UN UN Equity  APD UN Equity  \
# Date
# 1999-12-31            0.0       0.000000           0.0            0.0
# 2000-01-31           -0.0      -0.006169          -0.0           -0.0
# 2000-02-29           -0.0      -0.025896          -0.0           -0.0
# 2000-03-31            0.0       0.033601           0.0            0.0
# 2000-04-30            0.0       0.001610          -0.0            0.0
# ...                   ...            ...           ...            ...
# 2022-08-31            0.0       0.000000           0.0            0.0
# 2022-09-30           -0.0      -0.000000           0.0           -0.0
# 2022-10-31            0.0       0.000000           0.0            0.0
# 2022-11-30            0.0       0.000000           0.0            0.0
# 2022-12-31           -0.0       0.000000           0.0            0.0
#
#             RDPL UN Equity  GOLD UN Equity  VZ UN Equity  CAT UN Equity  \
# Date
# 1999-12-31             0.0             0.0      0.000000            0.0
# 2000-01-31            -0.0            -0.0     -0.000000           -0.0
# 2000-02-29            -0.0             0.0     -0.000000           -0.0
# 2000-03-31             0.0            -0.0      0.000000            0.0
# 2000-04-30            -0.0             0.0     -0.000000           -0.0
# ...                    ...             ...           ...            ...
# 2022-08-31             0.0            -0.0     -0.006365           -0.0
# 2022-09-30             0.0             0.0     -0.012208           -0.0
# 2022-10-31             0.0            -0.0     -0.000790            0.0
# 2022-11-30             0.0             0.0      0.003584            0.0
# 2022-12-31             0.0             0.0     -0.002153            0.0
#
#             CVX UN Equity  KO UN Equity  ...  QCOM UQ Equity  SPLS UQ Equity  \
# Date                                     ...
# 1999-12-31            0.0           0.0  ...             0.0             0.0
# 2000-01-31           -0.0          -0.0  ...            -0.0             0.0
# 2000-02-29           -0.0          -0.0  ...             0.0             0.0
# 2000-03-31            0.0          -0.0  ...             0.0            -0.0
# 2000-04-30           -0.0           0.0  ...            -0.0            -0.0
# ...                   ...           ...  ...             ...             ...
# 2022-08-31           -0.0          -0.0  ...            -0.0             0.0
# 2022-09-30           -0.0          -0.0  ...            -0.0             0.0
# 2022-10-31            0.0           0.0  ...             0.0             0.0
# 2022-11-30            0.0           0.0  ...             0.0             0.0
# 2022-12-31           -0.0           0.0  ...             0.0             0.0
#
#             XLNX UQ Equity  1519128D UQ Equity  NTAP UQ Equity  \
# Date
# 1999-12-31             0.0                 0.0             0.0
# 2000-01-31            -0.0                -0.0             0.0
# 2000-02-29             0.0                -0.0             0.0
# 2000-03-31             0.0                -0.0            -0.0
# 2000-04-30            -0.0                -0.0            -0.0
# ...                    ...                 ...             ...
# 2022-08-31             0.0                 0.0             0.0
# 2022-09-30             0.0                 0.0            -0.0
# 2022-10-31             0.0                 0.0             0.0
# 2022-11-30             0.0                 0.0             0.0
# 2022-12-31             0.0                 0.0            -0.0
#
#             CTXS UQ Equity  9990253D UN Equity  0948669D UN Equity  \
# Date
# 1999-12-31             0.0                 0.0                 0.0
# 2000-01-31             0.0                -0.0                -0.0
# 2000-02-29             0.0                -0.0                -0.0
# 2000-03-31            -0.0                 0.0                 0.0
# 2000-04-30            -0.0                 0.0                -0.0
# ...                    ...                 ...                 ...
# 2022-08-31             0.0                 0.0                 0.0
# 2022-09-30             0.0                 0.0                 0.0
# 2022-10-31             0.0                 0.0                 0.0
# 2022-11-30             0.0                 0.0                 0.0
# 2022-12-31             0.0                 0.0                 0.0
#
#             CMCSK UQ Equity    PF_ret
# Date
# 1999-12-31              0.0  0.000000
# 2000-01-31             -0.0 -0.060958
# 2000-02-29             -0.0 -0.140804
# 2000-03-31             -0.0  0.080517
# 2000-04-30             -0.0  0.049175
# ...                     ...       ...
# 2022-08-31              0.0  0.018985
# 2022-09-30              0.0 -0.188427
# 2022-10-31              0.0  0.103598
# 2022-11-30              0.0  0.001489
# 2022-12-31              0.0 -0.012038
#
# [277 rows x 501 columns]

# %%
weighted_ret['PF_ret'].agg(lambda x: ((1+x).prod()-1))
# Out:
# -0.9861375463067868

# %%
sb.ecdfplot(x = weighted_ret['PF_ret'])
# Out:
# <AxesSubplot:xlabel='PF_ret', ylabel='Proportion'>

# %% [markdown]
# # Approach 2 --> running 12-month avg of carry signal --> I just realized I rebalance weekly --> needs to be cared for

# %%
# the approach is as follows: 
# 1. take a moving average of the 12 month previous carry signal, ignoring the most recent month
# 2. for each month calculate the 10 stocks considered for the long strategy
# 3. calculate the PF return
# 4. take into account the transaction costs

# %%
# Loading Data (takes some time)

div = pd.read_excel("02_Data_clean/SPX_div_clean_Nick.xlsx", parse_dates=["Date"])
ret = pd.read_excel("02_Data_clean/SPX_px_clean_Nick.xlsx", parse_dates=["Date"])

# safe the div as divv in case we need it later
divv = div 

# reset the index to be a date
div = div.set_index(['Date'])
ret = ret.set_index(['Date'])

# Check
# print(type(div))
# print(div.dtypes)
# print(type(ret))
# print(ret.dtypes)

# %%
# create 12-month running avg of carry signal (i.e., div yield)
for i in range(52, len(div.index)):
    x = div.iloc[i-52:i,:].mean()
    div.iloc[i,:] = x

# %%
# in a first step we create a dataframe which we will fill with the weights of the carry strategy each month
### Important ### for carry we should use the (expected) dividend yield minus the riskfree ### Important ###
cols = divv.columns[1:]
rows = divv.iloc[:,0]

weights = pd.DataFrame(index = rows, columns = (cols))

# %%
# create weights dataframe

for i in div.index:
    x = div.loc[i,:].nlargest(10)
    for j in div.columns:
        if j in x.index:
            weights.loc[i,j] = 0.1
        else:
            weights.loc[i,j] = 0

weighted_ret = weights
weights
# Out:
#            AEE UN Equity ITT UN Equity UN UN Equity APD UN Equity  \
# Date
# 1999-12-31             0           0.1            0             0
# 2000-01-07             0           0.1            0             0
# 2000-01-14             0           0.1            0             0
# 2000-01-21             0           0.1            0             0
# 2000-01-28             0           0.1            0             0
# ...                  ...           ...          ...           ...
# 2022-11-04             0           0.1            0             0
# 2022-11-11             0           0.1            0             0
# 2022-11-18             0           0.1            0             0
# 2022-11-25             0           0.1            0             0
# 2022-12-02             0           0.1            0             0
#
#            RDPL UN Equity GOLD UN Equity VZ UN Equity CAT UN Equity  \
# Date
# 1999-12-31              0              0            0             0
# 2000-01-07              0              0            0             0
# 2000-01-14              0              0            0             0
# 2000-01-21              0              0            0             0
# 2000-01-28              0              0            0             0
# ...                   ...            ...          ...           ...
# 2022-11-04              0              0            0             0
# 2022-11-11              0              0            0             0
# 2022-11-18              0              0            0             0
# 2022-11-25              0              0            0             0
# 2022-12-02              0              0            0             0
#
#            CVX UN Equity KO UN Equity  ... PTC UQ Equity QCOM UQ Equity  \
# Date                                   ...
# 1999-12-31             0            0  ...             0              0
# 2000-01-07             0            0  ...             0              0
# 2000-01-14             0            0  ...             0              0
# 2000-01-21             0            0  ...             0              0
# 2000-01-28             0            0  ...             0              0
# ...                  ...          ...  ...           ...            ...
# 2022-11-04             0            0  ...             0              0
# 2022-11-11             0            0  ...             0              0
# 2022-11-18             0            0  ...             0              0
# 2022-11-25             0            0  ...             0              0
# 2022-12-02             0            0  ...             0              0
#
#            SPLS UQ Equity XLNX UQ Equity 1519128D UQ Equity NTAP UQ Equity  \
# Date
# 1999-12-31              0              0                  0              0
# 2000-01-07              0              0                  0              0
# 2000-01-14              0              0                  0              0
# 2000-01-21              0              0                  0              0
# 2000-01-28              0              0                  0              0
# ...                   ...            ...                ...            ...
# 2022-11-04              0              0                  0              0
# 2022-11-11              0              0                  0              0
# 2022-11-18              0              0                  0              0
# 2022-11-25              0              0                  0              0
# 2022-12-02              0              0                  0              0
#
#            CTXS UQ Equity 9990253D UN Equity 0948669D UN Equity  \
# Date
# 1999-12-31              0                  0                  0
# 2000-01-07              0                  0                  0
# 2000-01-14              0                  0                  0
# 2000-01-21              0                  0                  0
# 2000-01-28              0                  0                  0
# ...                   ...                ...                ...
# 2022-11-04              0                  0                  0
# 2022-11-11              0                  0                  0
# 2022-11-18              0                  0                  0
# 2022-11-25              0                  0                  0
# 2022-12-02              0                  0                  0
#
#            CMCSK UQ Equity
# Date
# 1999-12-31               0
# 2000-01-07               0
# 2000-01-14               0
# 2000-01-21               0
# 2000-01-28               0
# ...                    ...
# 2022-11-04               0
# 2022-11-11               0
# 2022-11-18               0
# 2022-11-25               0
# 2022-12-02               0
#
# [1197 rows x 500 columns]

# %%
# calculate PF returns (takes ages)

for i in weighted_ret.index[52:]:
    for j in weighted_ret.columns:
        weighted_ret.loc[i,j] = weighted_ret.loc[i,j]*ret.loc[i,j]
        
weighted_ret['PF_ret'] = 0
weighted_ret

# first 52 weeks have no return calculated since they are only used for PF weights creation in 2000-12
# Out:
#            AEE UN Equity ITT UN Equity UN UN Equity APD UN Equity  \
# Date
# 1999-12-31             0           0.1            0             0
# 2000-01-07             0           0.1            0             0
# 2000-01-14             0           0.1            0             0
# 2000-01-21             0           0.1            0             0
# 2000-01-28             0           0.1            0             0
# ...                  ...           ...          ...           ...
# 2022-11-04          -0.0     -0.001754          NaN           0.0
# 2022-11-11           0.0       0.00923          NaN           0.0
# 2022-11-18           0.0      0.002046          NaN           0.0
# 2022-11-25           0.0      0.000344          NaN           0.0
# 2022-12-02          -0.0      0.000201          NaN           0.0
#
#            RDPL UN Equity GOLD UN Equity VZ UN Equity CAT UN Equity  \
# Date
# 1999-12-31              0              0            0             0
# 2000-01-07              0              0            0             0
# 2000-01-14              0              0            0             0
# 2000-01-21              0              0            0             0
# 2000-01-28              0              0            0             0
# ...                   ...            ...          ...           ...
# 2022-11-04            NaN           -0.0         -0.0           0.0
# 2022-11-11            NaN            0.0          0.0           0.0
# 2022-11-18            NaN           -0.0          0.0          -0.0
# 2022-11-25            NaN            0.0          0.0           0.0
# 2022-12-02            NaN            0.0         -0.0           0.0
#
#            CVX UN Equity KO UN Equity  ... QCOM UQ Equity SPLS UQ Equity  \
# Date                                   ...
# 1999-12-31             0            0  ...              0              0
# 2000-01-07             0            0  ...              0              0
# 2000-01-14             0            0  ...              0              0
# 2000-01-21             0            0  ...              0              0
# 2000-01-28             0            0  ...              0              0
# ...                  ...          ...  ...            ...            ...
# 2022-11-04           0.0         -0.0  ...           -0.0            NaN
# 2022-11-11           0.0          0.0  ...            0.0            NaN
# 2022-11-18          -0.0         -0.0  ...            0.0            NaN
# 2022-11-25           0.0          0.0  ...           -0.0            NaN
# 2022-12-02          -0.0          0.0  ...            0.0            NaN
#
#            XLNX UQ Equity 1519128D UQ Equity NTAP UQ Equity CTXS UQ Equity  \
# Date
# 1999-12-31              0                  0              0              0
# 2000-01-07              0                  0              0              0
# 2000-01-14              0                  0              0              0
# 2000-01-21              0                  0              0              0
# 2000-01-28              0                  0              0              0
# ...                   ...                ...            ...            ...
# 2022-11-04            NaN                NaN           -0.0            NaN
# 2022-11-11            NaN                NaN            0.0            NaN
# 2022-11-18            NaN                NaN            0.0            NaN
# 2022-11-25            NaN                NaN            0.0            NaN
# 2022-12-02            NaN                NaN           -0.0            NaN
#
#            9990253D UN Equity 0948669D UN Equity CMCSK UQ Equity PF_ret
# Date
# 1999-12-31                  0                  0               0      0
# 2000-01-07                  0                  0               0      0
# 2000-01-14                  0                  0               0      0
# 2000-01-21                  0                  0               0      0
# 2000-01-28                  0                  0               0      0
# ...                       ...                ...             ...    ...
# 2022-11-04                NaN                NaN             NaN      0
# 2022-11-11                NaN                NaN             NaN      0
# 2022-11-18                NaN                NaN             NaN      0
# 2022-11-25                NaN                NaN             NaN      0
# 2022-12-02                NaN                NaN             NaN      0
#
# [1197 rows x 501 columns]

# %%
# now we sum over each row to calculate the PF return and put it in the respective columns

for i in weighted_ret.index[52:]:
    weighted_ret.loc[i,'PF_ret'] = weighted_ret.loc[i,:].sum()

weighted_ret
# Out:
#            AEE UN Equity ITT UN Equity UN UN Equity APD UN Equity  \
# Date
# 1999-12-31             0           0.1            0             0
# 2000-01-07             0           0.1            0             0
# 2000-01-14             0           0.1            0             0
# 2000-01-21             0           0.1            0             0
# 2000-01-28             0           0.1            0             0
# ...                  ...           ...          ...           ...
# 2022-11-04          -0.0     -0.001754          NaN           0.0
# 2022-11-11           0.0       0.00923          NaN           0.0
# 2022-11-18           0.0      0.002046          NaN           0.0
# 2022-11-25           0.0      0.000344          NaN           0.0
# 2022-12-02          -0.0      0.000201          NaN           0.0
#
#            RDPL UN Equity GOLD UN Equity VZ UN Equity CAT UN Equity  \
# Date
# 1999-12-31              0              0            0             0
# 2000-01-07              0              0            0             0
# 2000-01-14              0              0            0             0
# 2000-01-21              0              0            0             0
# 2000-01-28              0              0            0             0
# ...                   ...            ...          ...           ...
# 2022-11-04            NaN           -0.0         -0.0           0.0
# 2022-11-11            NaN            0.0          0.0           0.0
# 2022-11-18            NaN           -0.0          0.0          -0.0
# 2022-11-25            NaN            0.0          0.0           0.0
# 2022-12-02            NaN            0.0         -0.0           0.0
#
#            CVX UN Equity KO UN Equity  ... QCOM UQ Equity SPLS UQ Equity  \
# Date                                   ...
# 1999-12-31             0            0  ...              0              0
# 2000-01-07             0            0  ...              0              0
# 2000-01-14             0            0  ...              0              0
# 2000-01-21             0            0  ...              0              0
# 2000-01-28             0            0  ...              0              0
# ...                  ...          ...  ...            ...            ...
# 2022-11-04           0.0         -0.0  ...           -0.0            NaN
# 2022-11-11           0.0          0.0  ...            0.0            NaN
# 2022-11-18          -0.0         -0.0  ...            0.0            NaN
# 2022-11-25           0.0          0.0  ...           -0.0            NaN
# 2022-12-02          -0.0          0.0  ...            0.0            NaN
#
#            XLNX UQ Equity 1519128D UQ Equity NTAP UQ Equity CTXS UQ Equity  \
# Date
# 1999-12-31              0                  0              0              0
# 2000-01-07              0                  0              0              0
# 2000-01-14              0                  0              0              0
# 2000-01-21              0                  0              0              0
# 2000-01-28              0                  0              0              0
# ...                   ...                ...            ...            ...
# 2022-11-04            NaN                NaN           -0.0            NaN
# 2022-11-11            NaN                NaN            0.0            NaN
# 2022-11-18            NaN                NaN            0.0            NaN
# 2022-11-25            NaN                NaN            0.0            NaN
# 2022-12-02            NaN                NaN           -0.0            NaN
#
#            9990253D UN Equity 0948669D UN Equity CMCSK UQ Equity    PF_ret
# Date
# 1999-12-31                  0                  0               0  0.000000
# 2000-01-07                  0                  0               0  0.000000
# 2000-01-14                  0                  0               0  0.000000
# 2000-01-21                  0                  0               0  0.000000
# 2000-01-28                  0                  0               0  0.000000
# ...                       ...                ...             ...       ...
# 2022-11-04                NaN                NaN             NaN  0.006965
# 2022-11-11                NaN                NaN             NaN  0.013816
# 2022-11-18                NaN                NaN             NaN -0.001155
# 2022-11-25                NaN                NaN             NaN  0.006999
# 2022-12-02                NaN                NaN             NaN  0.011768
#
# [1197 rows x 501 columns]

# %%
weighted_ret['PF_ret'].agg(lambda x: ((1+x).prod()-1))
# Out:
# 5.946021985907879

# %%
weighted_ret['PF_ret'].sum()
# Out:
# 2.345474670047323

# %%
x = [i for i in weighted_ret['PF_ret'] if i > 0.05]

# %%
y = [i for i in weighted_ret['PF_ret'] if i < -0.05]

# %%
sb.scatterplot(y = weighted_ret['PF_ret'], x = weighted_ret.index, s = 5)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='PF_ret'>

# %%
sb.lineplot(y = weighted_ret['PF_ret'], x = weighted_ret.index)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='PF_ret'>

# %%
x = 1
for i in weighted_ret['PF_ret']:
    #print(i)
    x = (1+i)*x
PF_return_annual = (x**(1/20))-1

# yielding an annual return of 10%

# %%
PF_mean = weighted_ret['PF_ret'].mean()

# %%
PF_std = weighted_ret['PF_ret'].std() * (52)**0.5

# %%
(PF_return_annual - 0.01)/PF_std
# Out:
# 0.4887304351674354
